# %%
#This code will find the filler word from audio using both audio analysis and AWS transcript
#Inputs: audio files with .wav format
#Output: time when filler word occurs
#AWS transcripts for the 19 audios are picked from '/content/drive/MyDrive/Paleru_Khushi/Main_audios_for_testing_Json'
#Files this notebook refers: Excel sheet 'https://docs.google.com/spreadsheets/d/15JyW9TBGHSUhA4c3NOao0V6eYOikZ8x4/edit#gid=1805822620'
#Author: Khushi Pitroda
#Date: 19-July-2021

# %%
#Prerequisite
#.Wav (audio) files
#AWS transcripts for the 19 audios are picked from '/content/drive/MyDrive/Paleru_Khushi/Main_audios_for_testing_Json'
#parselmouth
#data from excel for predefined values

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Change directory 
#Go to shared with me folder create shortcut of shared folder and add it to the my drive so you can access that shared folder from here.

import os 
os.chdir("/content/drive/MyDrive/Paleru_Khushi")

# %%
pip install praat-parselmouth
# Out:
# Requirement already satisfied: praat-parselmouth in /usr/local/lib/python3.7/dist-packages (0.4.0)
# Requirement already satisfied: numpy>=1.7.0 in /usr/local/lib/python3.7/dist-packages (from praat-parselmouth) (1.19.5)

# %%
import json         #for reading json files

# %%
import parselmouth
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Before running this code, make sure the JSON file asrOutput.json is placed in the folder in the drive
#Make sure you have uploaded the audio file in AWS and dowloaded the JSON file in advance.
#Produces the transcript of the audio file

from operator import itemgetter           #for mapping
import math


for a in range(1,21):  
  if a == 3:
    continue
  print("---------------------------------------AUDIO - "+str(a)+"---------------------------------------")
  
  f = open("/content/drive/MyDrive/Paleru_Khushi/Main_audios_for_testing_Json/asrOutput"+str(a)+".json")           #create json file by uploading audio files (https://aws.amazon.com/getting-started/hands-on/create-audio-transcript-transcribe/)
  
  data = json.load(f)
  #print(data)
  #dictonary containing all information 
  x = data['results'] ['items']         #fetch result(keyname) from data and from result(sub-dictonary) fetch transcripts stores in list named x  
  words_dict = {}
  for i in range(1,len(x)):             #for getting each single word, start_time and start_time from the list
    time = []
    start_time = 0                      #initial value
    end_time = 0                        #initial value

    word = x[i]['alternatives'][0]['content']         #get the word- content from dictonary inside the list inside the dicrtonary named alternatives which is inside the list x. print(x) for more understanding.
    confidence = x[i]['alternatives'][0]['confidence'] 
    if word!='.' and word!=',' and word!='?':                       #punctuation doesn't have timestamps so ignoring it
      start_time = x[i]["start_time"]                 #from list getting value of start_time for each word- content
      end_time = x[i]['end_time']                     #from list getting value of end_time for each word- content
      list = [word,start_time,end_time,confidence]
      words_dict[start_time] = list
      #print(word)
    if word == 'Uh' or word =='um' or word =='Um' or word =='uh':
      print(f"AWS Filler detection: \nWord: {word}, start_time: {start_time}, end_time: {end_time}\n")        #printing all the values
  
  start_point_aws = 0
  end_point_aws = 0
  start_point_algo = 0
  end_point_algo = 0
  #print(words_dict)       
  def false_positive(start_point_algo, end_point_algo):
    flag = 1
    global start_point_aws, end_point_aws

    start_point_aws_prev =  start_point_aws
    end_point_aws_prev = end_point_aws
    diffrence_aws_prev = end_point_aws - start_point_aws

    start_point_algo_prev = start_point_algo
    end_point_algo_prev = end_point_algo
    diffrence_algo_prev = end_point_algo - start_point_algo

    diffrence_prev = diffrence_aws_prev - diffrence_algo_prev

    for key in words_dict:
      start_point_aws = float(words_dict[key][1])
      end_point_aws = float(words_dict[key][2])
      confidence = float(words_dict[key][3])
      word_aws = words_dict[key][0]

      diffrence_aws = end_point_aws - start_point_aws
      diffrence_algo = end_point_algo - start_point_algo

      diffrence = diffrence_aws - diffrence_algo
      #applying filters to remove false positives by comparing it with AWS transcript
      if start_point_algo < end_point_aws and end_point_algo < end_point_aws and end_point_algo > start_point_aws:
        #if word is detected from transcript
        if word_aws == 'Uh' or word_aws =='um' or word_aws =='Um' or word_aws =='uh':
          print(f"--------------------------FILLER WORD DETECTED:---------------------\nWord: {word_aws} start_point_aws: {start_point_aws}, end_point_aws: {end_point_aws} Duration : {end_point_aws-start_point_aws}, Actual_duration: {end_point_algo-start_point_algo}, confidence:{confidence}")        #printing all the values
          flag = 0
        elif start_point_aws == start_point_aws_prev:
          #repetition  filter
          if diffrence_algo_prev > diffrence_algo:
            print(f"FALSE POSITIVE WORD DETECTED:\nWord: {word_aws} start_point_aws: {start_point_aws} end_point_aws: {end_point_aws} Duration : {end_point_aws-start_point_aws}, Actual_duration: {end_point_algo-start_point_algo}, confidence:{confidence}")        #printing all the values
            flag = 0
          else:
            print(f"FILLER WORD:\nWord: {word_aws} start_point_aws: {start_point_aws} end_point_aws: {end_point_aws}Duration : {end_point_aws-start_point_aws}, Actual_duration: {end_point_algo-start_point_algo}, confidence:{confidence}")        #printing all the values
          start_point_aws_prev = start_point_aws
          flag = 0
        #if it's false positive
        else:
          print(f"FALSE POSITIVE WORD DETECTED:\nWord: {word_aws} start_point_aws: {start_point_aws} end_point_aws: {end_point_aws} Duration : {end_point_aws-start_point_aws}, Actual_duration: {end_point_algo-start_point_algo}, confidence:{confidence}")        #printing all the values
          start_point_aws_prev = start_point_aws
          end_point_aws_prev = start_point_aws
          start_point_algo_prev = start_point_algo
          end_point_algo_prev = end_point_algo
          flag = 0
        break
      #if nothing is in transcript
      elif start_point_algo < end_point_aws and end_point_algo > start_point_aws:
        print(f"Maybe a filler word: \nstart_point_algo {start_point_algo}, end_point_algo {end_point_algo}, Duration : {end_point_aws-start_point_aws}, confidence:{confidence}")   
        flag = 0
    if flag == 1:
      print("Maybe a filler word:")  
    print(f"start_point_algo {start_point_algo} minutes , end_point_algo {end_point_algo} minutes \n")
        



  snd = parselmouth.Sound('/content/drive/My Drive/Paleru_Khushi/Main audios for testing/P'+str(a)+'.wav') #for importing audio file with filler words
  pitch = snd.to_pitch()                 #finding pitch of that filler word

  times = pitch.ts()                    #for getting values of different time stamps according to pitch values
  hop_dur = .01   #predefined value for time step
  num_form = 4    #predefined value for max number of formants = the number of peaks with which the entire spectrum is modelled
  max_form_freq = 4500    #predefined value for maximum formant

  form = snd.to_formant_burg(time_step=hop_dur, max_number_of_formants=num_form, maximum_formant = max_form_freq, pre_emphasis_from=50.0)   #for getting formant values

  form_1_vals = []  #list for storing audio's f1
  form_2_vals = []  #list for storing audio's f2
  form_3_vals = []  #list for storing audio's f3
  form_4_vals = []  #list for storing audio's f4


  #values from data in 'https://docs.google.com/spreadsheets/d/15JyW9TBGHSUhA4c3NOao0V6eYOikZ8x4/edit#gid=1805822620'

  #for f1
  max_formant_f1 = 785       #Average Maximum value from audios (between range of Start_F1 and End_F1) based on excel sheet
  min_formant_f1 = 545       #Average Minimum value from audios (between range of Start_F1 and End_F1) based on excel sheet
  Max_Consecutive_Positive_Dev_f1 = 60     #Maximum difference between two consecutive formants. (Deviation)
  Max_Consecutive_Negative_Dev_f1 = -66    #Minimum difference between two consecutive formants. (Deviation)
  min_no_of_continuous_value_f1 = 13
  formant_f1 = 0
  i=1
  arr_f1 = []      #for storing the values of formants 
  temp_f1 = []
  j=0

  #for f2
  max_formant_f2 = 2390.201396       #Average Maximum value from audios (between range of Start_F2 and End_F2) based on excel sheet
  min_formant_f2 = 1027.659305       #Average Minimum value from audios (between range of Start_F2 and End_F2) based on excel sheet
  Max_Consecutive_Positive_Dev_f2 = 116.86   #Maximum difference between two consecutive formants. (Deviation)
  Max_Consecutive_Negative_Dev_f2 = -152.86    #Minimum difference between two consecutive formants. (Deviation)
  min_no_of_continuous_value_f2 = 13
  formant_f2 = 0
  arr_f2 = []      #for storing the values of formants 
  temp_f2 = []

  for dt in times:      #for loop used with average of time instants

      form_1_vals.append(form.get_value_at_time(1,dt))    #storing the values of f2 audio in list
      prev_formant_f1 = formant_f1      #storing formant in prev_formant variable for next iteration
      formant_f1 = form.get_value_at_time(1,dt)    #getting formant value at perticular time
      Dev_f1 = formant_f1-prev_formant_f1    #getting deviation from 2 formant-prev_formant (2 consecutive points)

      
      form_2_vals.append(form.get_value_at_time(2,dt))    #storing the values of f2 audio in list
      prev_formant_f2 = formant_f2      #storing formant in prev_formant variable for next iteration
      formant_f2 = form.get_value_at_time(2,dt)    #getting formant value at perticular time
      Dev_f2 = formant_f2-prev_formant_f2    #getting deviation from 2 formant-prev_formant (2 consecutive points)

      if str(formant_f1) != 'nan' and str(prev_formant_f1) != 'nan'  and str(formant_f2) != 'nan' and str(prev_formant_f2) != 'nan' :    #if both formats are not null
      #checking for conditions based on data, if formant is less than maximum formant acquired from excel, if formant is greater  than minimum formant, if deviation is between minimum and maximum  consecutive deviation then it'll go inside.
        # f1 and f2 filters
        if formant_f1 <max_formant_f1 and formant_f1 > min_formant_f1 and Dev_f1 < Max_Consecutive_Positive_Dev_f1 and Dev_f1>Max_Consecutive_Negative_Dev_f1 and formant_f2 <max_formant_f2 and formant_f2 > min_formant_f2 and Dev_f2<Max_Consecutive_Positive_Dev_f2 and Dev_f2>Max_Consecutive_Negative_Dev_f2:   
          arr_f2.append(dt)   #if all conditions are satisfied then it'll store that time in arr 
          i=i+1            #increment of i (i is for consecutive points)
        else:           #if all 4 conditions are not fulfilled then i will be zero and array will be empty 
          j=i
          temp_f2 = arr_f2
          i=0
          arr_f2 = []
      if j > min_no_of_continuous_value_f2:
        #print("f2")
        start_point_algo = 0
        end_point_algo = 0
        start_point_algo = temp_f2[0]
        end_point_algo = temp_f2[len(temp_f2)-1]
        
        j=0
        false_positive(start_point_algo,end_point_algo)
# Out:
# ---------------------------------------AUDIO - 1---------------------------------------
# AWS Filler detection:
# Word: Uh, start_time: 259.3, end_time: 259.64
#
# FALSE POSITIVE WORD DETECTED:
# Word: which start_point_aws: 2.43 end_point_aws: 3.07 Duration : 0.6399999999999997, Actual_duration: 0.15000000000000036, confidence:1.0
# start_point_algo 2.883354166666654 minutes , end_point_algo 3.0333541666666544 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: the start_point_aws: 5.78 end_point_aws: 6.12 Duration : 0.33999999999999986, Actual_duration: 0.15000000000000036, confidence:1.0
# start_point_algo 5.853354166666654 minutes , end_point_algo 6.003354166666655 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: collected start_point_aws: 44.14 end_point_aws: 44.79 Duration : 0.6499999999999986, Actual_duration: 0.13000000000000256, confidence:1.0
# start_point_algo 44.19335416666666 minutes , end_point_algo 44.32335416666666 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: directly start_point_aws: 51.52 end_point_aws: 52.31 Duration : 0.7899999999999991, Actual_duration: 0.240000000000002, confidence:1.0
# start_point_algo 51.58335416666666 minutes , end_point_algo 51.82335416666666 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: The start_point_aws: 57.51 end_point_aws: 57.88 Duration : 0.37000000000000455, Actual_duration: 0.259999999999998, confidence:1.0
# start_point_algo 57.58335416666666 minutes , end_point_algo 57.84335416666666 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: but start_point_aws: 80.34 end_point_aws: 80.77 Duration : 0.4299999999999926, Actual_duration: 0.1799999999999926, confidence:1.0
# start_point_algo 80.47335416666665 minutes , end_point_algo 80.65335416666665 minutes
#
# Maybe a filler word:
# start_point_algo 109.59335416666666, end_point_algo 109.72335416666665, Duration : 0.3400000000000034, confidence:0.937
# FALSE POSITIVE WORD DETECTED:
# Word: is start_point_aws: 109.69 end_point_aws: 109.8 Duration : 0.10999999999999943, Actual_duration: 0.12999999999999545, confidence:0.954
# start_point_algo 109.59335416666666 minutes , end_point_algo 109.72335416666665 minutes
#
# Maybe a filler word:
# start_point_algo 132.45335416666666, end_point_algo 132.67335416666666, Duration : 0.5, confidence:0.521
# FALSE POSITIVE WORD DETECTED:
# Word: doing start_point_aws: 132.65 end_point_aws: 133.11 Duration : 0.46000000000000796, Actual_duration: 0.21999999999999886, confidence:1.0
# start_point_algo 132.45335416666666 minutes , end_point_algo 132.67335416666666 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: if start_point_aws: 138.97 end_point_aws: 139.91 Duration : 0.9399999999999977, Actual_duration: 0.14999999999997726, confidence:1.0
# start_point_algo 139.44335416666667 minutes , end_point_algo 139.59335416666664 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: under start_point_aws: 152.23 end_point_aws: 152.84 Duration : 0.6100000000000136, Actual_duration: 0.18999999999999773, confidence:0.999
# start_point_algo 152.42335416666666 minutes , end_point_algo 152.61335416666665 minutes
#
# Maybe a filler word:
# start_point_algo 152.70335416666666, end_point_algo 152.87335416666664, Duration : 0.6100000000000136, confidence:0.999
# FALSE POSITIVE WORD DETECTED:
# Word: under start_point_aws: 152.85 end_point_aws: 153.38 Duration : 0.5300000000000011, Actual_duration: 0.1699999999999875, confidence:1.0
# start_point_algo 152.70335416666666 minutes , end_point_algo 152.87335416666664 minutes
#
# Maybe a filler word:
# start_point_algo 173.93335416666665, end_point_algo 174.10335416666666, Duration : 0.3100000000000023, confidence:0.9
# FALSE POSITIVE WORD DETECTED:
# Word: is start_point_aws: 174.05 end_point_aws: 174.2 Duration : 0.14999999999997726, Actual_duration: 0.17000000000001592, confidence:0.9
# start_point_algo 173.93335416666665 minutes , end_point_algo 174.10335416666666 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: order start_point_aws: 205.28 end_point_aws: 205.89 Duration : 0.6099999999999852, Actual_duration: 0.12999999999999545, confidence:0.999
# start_point_algo 205.51335416666666 minutes , end_point_algo 205.64335416666665 minutes
#
# Maybe a filler word:
# start_point_algo 218.61335416666665, end_point_algo 218.75335416666667, Duration : 0.21000000000000796, confidence:0.519
# FALSE POSITIVE WORD DETECTED:
# Word: tracing start_point_aws: 218.72 end_point_aws: 219.38 Duration : 0.6599999999999966, Actual_duration: 0.14000000000001478, confidence:1.0
# start_point_algo 218.61335416666665 minutes , end_point_algo 218.75335416666667 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: correct start_point_aws: 220.81 end_point_aws: 221.15 Duration : 0.3400000000000034, Actual_duration: 0.13999999999998636, confidence:1.0
# start_point_algo 220.89335416666665 minutes , end_point_algo 221.03335416666664 minutes
#
# Maybe a filler word:
# start_point_algo 237.43335416666665, end_point_algo 237.58335416666665, Duration : 0.3499999999999943, confidence:0.979
# FALSE POSITIVE WORD DETECTED:
# Word: of start_point_aws: 237.48 end_point_aws: 237.63 Duration : 0.15000000000000568, Actual_duration: 0.15000000000000568, confidence:1.0
# start_point_algo 237.43335416666665 minutes , end_point_algo 237.58335416666665 minutes
#
# Maybe a filler word:
# start_point_algo 259.48335416666663, end_point_algo 259.64335416666665, Duration : 0.339999999999975, confidence:0.555
# start_point_algo 259.48335416666663 minutes , end_point_algo 259.64335416666665 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: earlier start_point_aws: 298.08 end_point_aws: 298.84 Duration : 0.7599999999999909, Actual_duration: 0.1500000000000341, confidence:1.0
# start_point_algo 298.10335416666663 minutes , end_point_algo 298.25335416666667 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: investment start_point_aws: 375.81 end_point_aws: 376.81 Duration : 1.0, Actual_duration: 0.2400000000000091, confidence:1.0
# start_point_algo 376.16335416666664 minutes , end_point_algo 376.40335416666665 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: just start_point_aws: 381.34 end_point_aws: 381.93 Duration : 0.5900000000000318, Actual_duration: 0.18999999999999773, confidence:1.0
# start_point_algo 381.15335416666665 minutes , end_point_algo 381.34335416666664 minutes
#
# Maybe a filler word:
# start_point_algo 386.81335416666667 minutes , end_point_algo 386.96335416666665 minutes
#
# ---------------------------------------AUDIO - 2---------------------------------------
# AWS Filler detection:
# Word: Uh, start_time: 3.87, end_time: 4.82
#
# AWS Filler detection:
# Word: uh, start_time: 147.76, end_time: 148.64
#
# AWS Filler detection:
# Word: uh, start_time: 228.78, end_time: 229.08
#
# FALSE POSITIVE WORD DETECTED:
# Word: interest start_point_aws: 34.07 end_point_aws: 34.9 Duration : 0.8299999999999983, Actual_duration: 0.1700000000000017, confidence:0.682
# start_point_algo 34.350406249999985 minutes , end_point_algo 34.520406249999986 minutes
#
# Maybe a filler word:
# start_point_algo 39.34040624999999, end_point_algo 39.61040624999999, Duration : 0.28999999999999915, confidence:1.0
# Maybe a filler word:
# start_point_algo 39.34040624999999, end_point_algo 39.61040624999999, Duration : 0.060000000000002274, confidence:0.503
# FALSE POSITIVE WORD DETECTED:
# Word: belong start_point_aws: 39.58 end_point_aws: 39.95 Duration : 0.37000000000000455, Actual_duration: 0.2700000000000031, confidence:0.956
# start_point_algo 39.34040624999999 minutes , end_point_algo 39.61040624999999 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: how start_point_aws: 45.81 end_point_aws: 46.32 Duration : 0.509999999999998, Actual_duration: 0.13000000000000256, confidence:1.0
# start_point_algo 46.100406249999985 minutes , end_point_algo 46.23040624999999 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: problem start_point_aws: 51.34 end_point_aws: 51.75 Duration : 0.4099999999999966, Actual_duration: 0.13000000000000256, confidence:0.957
# start_point_algo 51.44040624999999 minutes , end_point_algo 51.57040624999999 minutes
#
# Maybe a filler word:
# start_point_algo 54.50040624999999, end_point_algo 54.72040624999999, Duration : 0.1600000000000037, confidence:0.992
# FALSE POSITIVE WORD DETECTED:
# Word: target start_point_aws: 54.64 end_point_aws: 55.04 Duration : 0.3999999999999986, Actual_duration: 0.21999999999999886, confidence:1.0
# start_point_algo 54.50040624999999 minutes , end_point_algo 54.72040624999999 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: content start_point_aws: 56.19 end_point_aws: 56.76 Duration : 0.5700000000000003, Actual_duration: 0.14000000000000057, confidence:0.998
# start_point_algo 56.530406249999984 minutes , end_point_algo 56.670406249999985 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: research start_point_aws: 61.8 end_point_aws: 63.06 Duration : 1.2600000000000051, Actual_duration: 0.14999999999999858, confidence:0.884
# start_point_algo 61.80040624999999 minutes , end_point_algo 61.950406249999986 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: trends start_point_aws: 63.91 end_point_aws: 64.31 Duration : 0.4000000000000057, Actual_duration: 0.14999999999999147, confidence:1.0
# start_point_algo 64.01040624999999 minutes , end_point_algo 64.16040624999998 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: trends start_point_aws: 66.99 end_point_aws: 67.42 Duration : 0.4300000000000068, Actual_duration: 0.14000000000000057, confidence:1.0
# start_point_algo 67.08040624999998 minutes , end_point_algo 67.22040624999998 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: and start_point_aws: 67.42 end_point_aws: 67.62 Duration : 0.20000000000000284, Actual_duration: 0.13000000000000966, confidence:1.0
# start_point_algo 67.43040624999998 minutes , end_point_algo 67.56040624999999 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: that start_point_aws: 96.47 end_point_aws: 96.68 Duration : 0.21000000000000796, Actual_duration: 0.12999999999999545, confidence:0.999
# start_point_algo 96.53040624999998 minutes , end_point_algo 96.66040624999998 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: problems start_point_aws: 125.3 end_point_aws: 125.79 Duration : 0.4900000000000091, Actual_duration: 0.14000000000000057, confidence:1.0
# start_point_algo 125.41040624999998 minutes , end_point_algo 125.55040624999998 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: customers start_point_aws: 127.43 end_point_aws: 127.94 Duration : 0.5099999999999909, Actual_duration: 0.14000000000000057, confidence:1.0
# start_point_algo 127.55040624999998 minutes , end_point_algo 127.69040624999998 minutes
#
# Maybe a filler word:
# start_point_algo 137.32040625, end_point_algo 137.46040624999998, Duration : 0.19999999999998863, confidence:0.524
# FALSE POSITIVE WORD DETECTED:
# Word: much start_point_aws: 137.38 end_point_aws: 137.6 Duration : 0.21999999999999886, Actual_duration: 0.13999999999998636, confidence:0.524
# start_point_algo 137.32040625 minutes , end_point_algo 137.46040624999998 minutes
#
# Maybe a filler word:
# start_point_algo 137.84040624999997, end_point_algo 138.05040624999998, Duration : 0.37000000000000455, confidence:1.0
# FALSE POSITIVE WORD DETECTED:
# Word: and start_point_aws: 137.97 end_point_aws: 138.42 Duration : 0.44999999999998863, Actual_duration: 0.21000000000000796, confidence:1.0
# start_point_algo 137.84040624999997 minutes , end_point_algo 138.05040624999998 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: soviet start_point_aws: 148.95 end_point_aws: 149.41 Duration : 0.46000000000000796, Actual_duration: 0.12999999999999545, confidence:0.997
# start_point_algo 149.10040625 minutes , end_point_algo 149.23040625 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: customer start_point_aws: 153.97 end_point_aws: 154.38 Duration : 0.4099999999999966, Actual_duration: 0.13000000000002387, confidence:0.995
# start_point_algo 154.06040624999997 minutes , end_point_algo 154.19040625 minutes
#
# Maybe a filler word:
# start_point_algo 154.35040625, end_point_algo 154.48040625, Duration : 0.4099999999999966, confidence:0.995
# FALSE POSITIVE WORD DETECTED:
# Word: it start_point_aws: 154.38 end_point_aws: 154.5 Duration : 0.12000000000000455, Actual_duration: 0.12999999999999545, confidence:0.991
# start_point_algo 154.35040625 minutes , end_point_algo 154.48040625 minutes
#
# Maybe a filler word:
# start_point_algo 160.57040625, end_point_algo 160.72040625, Duration : 0.18999999999999773, confidence:0.997
# FALSE POSITIVE WORD DETECTED:
# Word: problem start_point_aws: 160.69 end_point_aws: 161.04 Duration : 0.3499999999999943, Actual_duration: 0.15000000000000568, confidence:1.0
# start_point_algo 160.57040625 minutes , end_point_algo 160.72040625 minutes
#
# Maybe a filler word:
# start_point_algo 163.43040624999998, end_point_algo 163.56040624999997, Duration : 0.21999999999999886, confidence:1.0
# FALSE POSITIVE WORD DETECTED:
# Word: is start_point_aws: 163.46 end_point_aws: 163.75 Duration : 0.28999999999999204, Actual_duration: 0.12999999999999545, confidence:1.0
# start_point_algo 163.43040624999998 minutes , end_point_algo 163.56040624999997 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: trends start_point_aws: 165.26 end_point_aws: 165.74 Duration : 0.4800000000000182, Actual_duration: 0.14999999999997726, confidence:0.626
# start_point_algo 165.38040625 minutes , end_point_algo 165.53040624999997 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: that's start_point_aws: 190.82 end_point_aws: 191.33 Duration : 0.5100000000000193, Actual_duration: 0.13000000000002387, confidence:0.85
# start_point_algo 191.00040624999997 minutes , end_point_algo 191.13040625 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: audience start_point_aws: 195.74 end_point_aws: 196.21 Duration : 0.46999999999999886, Actual_duration: 0.1599999999999966, confidence:1.0
# start_point_algo 195.74040624999998 minutes , end_point_algo 195.90040624999997 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: for start_point_aws: 206.19 end_point_aws: 206.55 Duration : 0.36000000000001364, Actual_duration: 0.12999999999999545, confidence:1.0
# start_point_algo 206.39040624999998 minutes , end_point_algo 206.52040624999998 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: alerted start_point_aws: 211.3 end_point_aws: 211.74 Duration : 0.4399999999999977, Actual_duration: 0.13999999999998636, confidence:1.0
# start_point_algo 211.45040625 minutes , end_point_algo 211.59040624999997 minutes
#
# Maybe a filler word:
# start_point_algo 234.41040625, end_point_algo 234.54040625, Duration : 0.11000000000001364, confidence:1.0
# Maybe a filler word:
# start_point_algo 234.41040625, end_point_algo 234.54040625, Duration : 0.04999999999998295, confidence:0.671
# FALSE POSITIVE WORD DETECTED:
# Word: specific start_point_aws: 234.48 end_point_aws: 235.0 Duration : 0.5200000000000102, Actual_duration: 0.12999999999999545, confidence:1.0
# start_point_algo 234.41040625 minutes , end_point_algo 234.54040625 minutes
#
# FILLER WORD:
# Word: specific start_point_aws: 234.48 end_point_aws: 235.0Duration : 0.5200000000000102, Actual_duration: 0.17000000000001592, confidence:1.0
# start_point_algo 234.78040624999997 minutes , end_point_algo 234.95040625 minutes
#
# Maybe a filler word:
# start_point_algo 237.04040625, end_point_algo 237.18040624999998, Duration : 0.18000000000000682, confidence:0.538
# FALSE POSITIVE WORD DETECTED:
# Word: idea start_point_aws: 237.12 end_point_aws: 237.41 Duration : 0.28999999999999204, Actual_duration: 0.13999999999998636, confidence:1.0
# start_point_algo 237.04040625 minutes , end_point_algo 237.18040624999998 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: that start_point_aws: 242.39 end_point_aws: 242.64 Duration : 0.25, Actual_duration: 0.1599999999999966, confidence:1.0
# start_point_algo 242.47040625 minutes , end_point_algo 242.63040625 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: organizing start_point_aws: 244.64 end_point_aws: 245.19 Duration : 0.5500000000000114, Actual_duration: 0.14999999999997726, confidence:0.88
# start_point_algo 244.66040625 minutes , end_point_algo 244.81040624999997 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: customer start_point_aws: 247.23 end_point_aws: 247.7 Duration : 0.46999999999999886, Actual_duration: 0.160000000000025, confidence:0.984
# start_point_algo 247.31040624999997 minutes , end_point_algo 247.47040625 minutes
#
# Maybe a filler word:
# start_point_algo 267.44040625, end_point_algo 267.63040625, Duration : 0.18999999999999773, confidence:1.0
# Maybe a filler word:
# start_point_algo 267.44040625, end_point_algo 267.63040625, Duration : 0.1400000000000432, confidence:1.0
# FALSE POSITIVE WORD DETECTED:
# Word: tools start_point_aws: 267.6 end_point_aws: 267.92 Duration : 0.3199999999999932, Actual_duration: 0.18999999999999773, confidence:0.45
# start_point_algo 267.44040625 minutes , end_point_algo 267.63040625 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: specify start_point_aws: 278.57 end_point_aws: 279.0 Duration : 0.4300000000000068, Actual_duration: 0.1400000000000432, confidence:0.69
# start_point_algo 278.73040625 minutes , end_point_algo 278.87040625000003 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: your start_point_aws: 288.3 end_point_aws: 289.15 Duration : 0.8499999999999659, Actual_duration: 0.18999999999999773, confidence:0.885
# start_point_algo 288.86040625000004 minutes , end_point_algo 289.05040625000004 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: platforms start_point_aws: 290.09 end_point_aws: 290.87 Duration : 0.7800000000000296, Actual_duration: 0.19999999999998863, confidence:1.0
# start_point_algo 290.43040625000003 minutes , end_point_algo 290.63040625 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: whether start_point_aws: 292.24 end_point_aws: 292.7 Duration : 0.45999999999997954, Actual_duration: 0.1400000000000432, confidence:1.0
# start_point_algo 292.35040625 minutes , end_point_algo 292.49040625000004 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: not start_point_aws: 293.49 end_point_aws: 293.8 Duration : 0.3100000000000023, Actual_duration: 0.14999999999997726, confidence:1.0
# start_point_algo 293.56040625 minutes , end_point_algo 293.71040625 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: how start_point_aws: 305.32 end_point_aws: 305.88 Duration : 0.5600000000000023, Actual_duration: 0.19999999999998863, confidence:1.0
# start_point_algo 305.32040625 minutes , end_point_algo 305.52040625 minutes
#
# Maybe a filler word:
# start_point_algo 318.42040625000004, end_point_algo 318.56040625, Duration : 0.5900000000000318, confidence:0.82
# FALSE POSITIVE WORD DETECTED:
# Word: whether start_point_aws: 318.55 end_point_aws: 318.82 Duration : 0.2699999999999818, Actual_duration: 0.13999999999998636, confidence:0.946
# start_point_algo 318.42040625000004 minutes , end_point_algo 318.56040625 minutes
#
# Maybe a filler word:
# start_point_algo 326.58040625, end_point_algo 326.77040625, Duration : 0.6399999999999864, confidence:1.0
# FALSE POSITIVE WORD DETECTED:
# Word: strategies start_point_aws: 326.66 end_point_aws: 327.6 Duration : 0.9399999999999977, Actual_duration: 0.18999999999999773, confidence:0.993
# start_point_algo 326.58040625 minutes , end_point_algo 326.77040625 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: support start_point_aws: 337.09 end_point_aws: 337.53 Duration : 0.4399999999999977, Actual_duration: 0.14999999999997726, confidence:1.0
# start_point_algo 337.17040625000004 minutes , end_point_algo 337.32040625 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: whether start_point_aws: 340.42 end_point_aws: 341.36 Duration : 0.9399999999999977, Actual_duration: 0.12999999999999545, confidence:1.0
# start_point_algo 341.11040625000004 minutes , end_point_algo 341.24040625000004 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: awareness start_point_aws: 341.6 end_point_aws: 342.13 Duration : 0.5299999999999727, Actual_duration: 0.13999999999998636, confidence:1.0
# start_point_algo 341.76040625 minutes , end_point_algo 341.90040625 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: desired start_point_aws: 357.54 end_point_aws: 357.98 Duration : 0.4399999999999977, Actual_duration: 0.19999999999998863, confidence:0.998
# start_point_algo 357.75040625 minutes , end_point_algo 357.95040625 minutes
#
# ---------------------------------------AUDIO - 4---------------------------------------
# AWS Filler detection:
# Word: Uh, start_time: 129.16, end_time: 130.13
#
# AWS Filler detection:
# Word: uh, start_time: 390.85, end_time: 391.54
#
# AWS Filler detection:
# Word: uh, start_time: 472.7, end_time: 473.36
#
# FALSE POSITIVE WORD DETECTED:
# Word: a start_point_aws: 14.32 end_point_aws: 14.58 Duration : 0.2599999999999998, Actual_duration: 0.14000000000000057, confidence:0.998
# start_point_algo 14.361187500000002 minutes , end_point_algo 14.501187500000002 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: Empowerment start_point_aws: 15.69 end_point_aws: 16.32 Duration : 0.6300000000000008, Actual_duration: 0.16000000000000014, confidence:1.0
# start_point_algo 15.941187500000002 minutes , end_point_algo 16.1011875 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: something start_point_aws: 16.44 end_point_aws: 17.03 Duration : 0.5899999999999999, Actual_duration: 0.129999999999999, confidence:1.0
# start_point_algo 16.5211875 minutes , end_point_algo 16.6511875 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: a start_point_aws: 17.51 end_point_aws: 18.08 Duration : 0.5699999999999967, Actual_duration: 0.21999999999999886, confidence:1.0
# start_point_algo 17.7111875 minutes , end_point_algo 17.9311875 minutes
#
# Maybe a filler word:
# start_point_algo 44.7111875, end_point_algo 44.93118750000001, Duration : 0.29000000000000625, confidence:0.981
# FALSE POSITIVE WORD DETECTED:
# Word: concept start_point_aws: 44.85 end_point_aws: 45.41 Duration : 0.5599999999999952, Actual_duration: 0.22000000000000597, confidence:1.0
# start_point_algo 44.7111875 minutes , end_point_algo 44.93118750000001 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: of start_point_aws: 63.59 end_point_aws: 63.79 Duration : 0.19999999999999574, Actual_duration: 0.1599999999999966, confidence:1.0
# start_point_algo 63.61118750000001 minutes , end_point_algo 63.7711875 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: Haryana start_point_aws: 71.73 end_point_aws: 72.56 Duration : 0.8299999999999983, Actual_duration: 0.14000000000000057, confidence:0.992
# start_point_algo 72.2111875 minutes , end_point_algo 72.3511875 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: around start_point_aws: 81.56 end_point_aws: 81.92 Duration : 0.35999999999999943, Actual_duration: 0.1700000000000017, confidence:1.0
# start_point_algo 81.6011875 minutes , end_point_algo 81.7711875 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: her start_point_aws: 98.42 end_point_aws: 98.64 Duration : 0.21999999999999886, Actual_duration: 0.13000000000000966, confidence:1.0
# start_point_algo 98.4611875 minutes , end_point_algo 98.5911875 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: or start_point_aws: 98.65 end_point_aws: 99.26 Duration : 0.6099999999999994, Actual_duration: 0.14000000000000057, confidence:1.0
# start_point_algo 98.6411875 minutes , end_point_algo 98.7811875 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: her start_point_aws: 106.8 end_point_aws: 107.32 Duration : 0.519999999999996, Actual_duration: 0.14000000000000057, confidence:1.0
# start_point_algo 106.8911875 minutes , end_point_algo 107.0311875 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: lower start_point_aws: 132.61 end_point_aws: 132.85 Duration : 0.23999999999998067, Actual_duration: 0.12999999999999545, confidence:1.0
# start_point_algo 132.7011875 minutes , end_point_algo 132.8311875 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: work start_point_aws: 172.55 end_point_aws: 173.01 Duration : 0.45999999999997954, Actual_duration: 0.15000000000000568, confidence:1.0
# start_point_algo 172.6711875 minutes , end_point_algo 172.8211875 minutes
#
# Maybe a filler word:
# start_point_algo 177.2711875, end_point_algo 177.4011875, Duration : 0.1799999999999784, confidence:1.0
# FALSE POSITIVE WORD DETECTED:
# Word: aspiration start_point_aws: 177.29 end_point_aws: 178.12 Duration : 0.8300000000000125, Actual_duration: 0.12999999999999545, confidence:1.0
# start_point_algo 177.2711875 minutes , end_point_algo 177.4011875 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: process start_point_aws: 201.75 end_point_aws: 202.26 Duration : 0.5099999999999909, Actual_duration: 0.1599999999999966, confidence:0.998
# start_point_algo 201.8311875 minutes , end_point_algo 201.9911875 minutes
#
# Maybe a filler word:
# start_point_algo 204.7011875, end_point_algo 204.8311875, Duration : 0.2599999999999909, confidence:1.0
# FALSE POSITIVE WORD DETECTED:
# Word: what start_point_aws: 204.8 end_point_aws: 205.17 Duration : 0.3699999999999761, Actual_duration: 0.12999999999999545, confidence:0.974
# start_point_algo 204.7011875 minutes , end_point_algo 204.8311875 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: that start_point_aws: 213.91 end_point_aws: 214.2 Duration : 0.28999999999999204, Actual_duration: 0.13999999999998636, confidence:1.0
# start_point_algo 214.0411875 minutes , end_point_algo 214.1811875 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: that start_point_aws: 219.74 end_point_aws: 220.19 Duration : 0.44999999999998863, Actual_duration: 0.18999999999999773, confidence:1.0
# start_point_algo 219.7911875 minutes , end_point_algo 219.9811875 minutes
#
# Maybe a filler word:
# start_point_algo 221.6611875, end_point_algo 221.8511875, Duration : 0.4399999999999977, confidence:1.0
# FALSE POSITIVE WORD DETECTED:
# Word: education start_point_aws: 221.8 end_point_aws: 222.39 Duration : 0.589999999999975, Actual_duration: 0.18999999999999773, confidence:1.0
# start_point_algo 221.6611875 minutes , end_point_algo 221.8511875 minutes
#
# Maybe a filler word:
# start_point_algo 227.7311875, end_point_algo 227.9711875, Duration : 0.3599999999999852, confidence:1.0
# FALSE POSITIVE WORD DETECTED:
# Word: starts start_point_aws: 227.95 end_point_aws: 228.52 Duration : 0.5700000000000216, Actual_duration: 0.2400000000000091, confidence:1.0
# start_point_algo 227.7311875 minutes , end_point_algo 227.9711875 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: now start_point_aws: 279.16 end_point_aws: 279.84 Duration : 0.67999999999995, Actual_duration: 0.1300000000000523, confidence:1.0
# start_point_algo 279.2911875 minutes , end_point_algo 279.42118750000003 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: confidence start_point_aws: 286.09 end_point_aws: 286.95 Duration : 0.8600000000000136, Actual_duration: 0.160000000000025, confidence:1.0
# start_point_algo 286.6411875 minutes , end_point_algo 286.8011875 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: survey start_point_aws: 292.23 end_point_aws: 292.7 Duration : 0.46999999999997044, Actual_duration: 0.3300000000000409, confidence:1.0
# start_point_algo 292.2311875 minutes , end_point_algo 292.5611875 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: there start_point_aws: 304.31 end_point_aws: 304.83 Duration : 0.5199999999999818, Actual_duration: 0.18999999999999773, confidence:0.969
# start_point_algo 304.3911875 minutes , end_point_algo 304.5811875 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: things start_point_aws: 306.81 end_point_aws: 307.41 Duration : 0.6000000000000227, Actual_duration: 0.18000000000000682, confidence:0.999
# start_point_algo 306.8211875 minutes , end_point_algo 307.0011875 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: around start_point_aws: 308.41 end_point_aws: 308.93 Duration : 0.5199999999999818, Actual_duration: 0.18999999999999773, confidence:1.0
# start_point_algo 308.5311875 minutes , end_point_algo 308.7211875 minutes
#
# Maybe a filler word:
# start_point_algo 309.3911875, end_point_algo 309.67118750000003, Duration : 0.30000000000001137, confidence:1.0
# FALSE POSITIVE WORD DETECTED:
# Word: expense start_point_aws: 309.64 end_point_aws: 310.21 Duration : 0.5699999999999932, Actual_duration: 0.28000000000002956, confidence:1.0
# start_point_algo 309.3911875 minutes , end_point_algo 309.67118750000003 minutes
#
# FILLER WORD:
# Word: expense start_point_aws: 309.64 end_point_aws: 310.21Duration : 0.5699999999999932, Actual_duration: 0.12999999999999545, confidence:1.0
# start_point_algo 309.9411875 minutes , end_point_algo 310.0711875 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: what start_point_aws: 311.34 end_point_aws: 311.7 Duration : 0.36000000000001364, Actual_duration: 0.13999999999998636, confidence:1.0
# start_point_algo 311.4411875 minutes , end_point_algo 311.5811875 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: the start_point_aws: 311.71 end_point_aws: 312.52 Duration : 0.8100000000000023, Actual_duration: 0.29000000000002046, confidence:0.952
# start_point_algo 311.7311875 minutes , end_point_algo 312.0211875 minutes
#
# Maybe a filler word:
# start_point_algo 325.5111875, end_point_algo 325.8311875, Duration : 0.4000000000000341, confidence:1.0
# FALSE POSITIVE WORD DETECTED:
# Word: steps start_point_aws: 325.81 end_point_aws: 326.34 Duration : 0.5299999999999727, Actual_duration: 0.3199999999999932, confidence:0.756
# start_point_algo 325.5111875 minutes , end_point_algo 325.8311875 minutes
#
# FILLER WORD:
# Word: steps start_point_aws: 325.81 end_point_aws: 326.34Duration : 0.5299999999999727, Actual_duration: 0.12999999999999545, confidence:0.756
# start_point_algo 326.1211875 minutes , end_point_algo 326.2511875 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: in start_point_aws: 333.22 end_point_aws: 333.7 Duration : 0.47999999999996135, Actual_duration: 0.19000000000005457, confidence:1.0
# start_point_algo 333.2311875 minutes , end_point_algo 333.42118750000003 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: can start_point_aws: 335.4 end_point_aws: 335.68 Duration : 0.28000000000002956, Actual_duration: 0.14999999999997726, confidence:1.0
# start_point_algo 335.5111875 minutes , end_point_algo 335.6611875 minutes
#
# Maybe a filler word:
# start_point_algo 348.5111875, end_point_algo 348.6411875, Duration : 0.18000000000000682, confidence:0.982
# FALSE POSITIVE WORD DETECTED:
# Word: does start_point_aws: 348.62 end_point_aws: 348.87 Duration : 0.25, Actual_duration: 0.12999999999999545, confidence:0.964
# start_point_algo 348.5111875 minutes , end_point_algo 348.6411875 minutes
#
# Maybe a filler word:
# start_point_algo 355.0611875, end_point_algo 355.1911875, Duration : 0.08999999999997499, confidence:0.836
# FALSE POSITIVE WORD DETECTED:
# Word: house start_point_aws: 355.14 end_point_aws: 355.54 Duration : 0.4000000000000341, Actual_duration: 0.12999999999999545, confidence:1.0
# start_point_algo 355.0611875 minutes , end_point_algo 355.1911875 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: women start_point_aws: 372.85 end_point_aws: 373.68 Duration : 0.8299999999999841, Actual_duration: 0.15999999999996817, confidence:1.0
# start_point_algo 372.8711875 minutes , end_point_algo 373.0311875 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: like start_point_aws: 373.69 end_point_aws: 374.51 Duration : 0.8199999999999932, Actual_duration: 0.37000000000000455, confidence:0.986
# start_point_algo 373.7211875 minutes , end_point_algo 374.0911875 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: with start_point_aws: 379.37 end_point_aws: 380.04 Duration : 0.6700000000000159, Actual_duration: 0.2599999999999909, confidence:1.0
# start_point_algo 379.7411875 minutes , end_point_algo 380.0011875 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: men's start_point_aws: 381.21 end_point_aws: 382.14 Duration : 0.9300000000000068, Actual_duration: 0.2899999999999636, confidence:0.711
# start_point_algo 381.2511875 minutes , end_point_algo 381.5411875 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: dominated start_point_aws: 382.15 end_point_aws: 383.01 Duration : 0.8600000000000136, Actual_duration: 0.14999999999997726, confidence:0.983
# start_point_algo 382.2411875 minutes , end_point_algo 382.3911875 minutes
#
# --------------------------FILLER WORD DETECTED:---------------------
# Word: uh start_point_aws: 390.85, end_point_aws: 391.54 Duration : 0.6899999999999977, Actual_duration: 0.160000000000025, confidence:1.0
# start_point_algo 391.0111875 minutes , end_point_algo 391.17118750000003 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: power start_point_aws: 400.66 end_point_aws: 400.99 Duration : 0.3299999999999841, Actual_duration: 0.17000000000001592, confidence:1.0
# start_point_algo 400.7811875 minutes , end_point_algo 400.9511875 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: her start_point_aws: 410.28 end_point_aws: 410.72 Duration : 0.44000000000005457, Actual_duration: 0.14999999999997726, confidence:0.999
# start_point_algo 410.3711875 minutes , end_point_algo 410.5211875 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: about start_point_aws: 416.22 end_point_aws: 416.73 Duration : 0.5099999999999909, Actual_duration: 0.12999999999999545, confidence:1.0
# start_point_algo 416.42118750000003 minutes , end_point_algo 416.5511875 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: work start_point_aws: 424.7 end_point_aws: 425.01 Duration : 0.3100000000000023, Actual_duration: 0.18000000000000682, confidence:1.0
# start_point_algo 424.8011875 minutes , end_point_algo 424.98118750000003 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: does start_point_aws: 432.42 end_point_aws: 432.91 Duration : 0.4900000000000091, Actual_duration: 0.17000000000001592, confidence:1.0
# start_point_algo 432.6311875 minutes , end_point_algo 432.8011875 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: less start_point_aws: 437.07 end_point_aws: 437.36 Duration : 0.29000000000002046, Actual_duration: 0.12999999999999545, confidence:1.0
# start_point_algo 437.1511875 minutes , end_point_algo 437.2811875 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: ever start_point_aws: 462.55 end_point_aws: 463.06 Duration : 0.5099999999999909, Actual_duration: 0.15999999999996817, confidence:1.0
# start_point_algo 462.8111875 minutes , end_point_algo 462.9711875 minutes
#
# Maybe a filler word:
# start_point_algo 476.0611875, end_point_algo 476.2211875, Duration : 0.2999999999999545, confidence:0.999
# FALSE POSITIVE WORD DETECTED:
# Word: to start_point_aws: 476.16 end_point_aws: 476.3 Duration : 0.13999999999998636, Actual_duration: 0.15999999999996817, confidence:1.0
# start_point_algo 476.0611875 minutes , end_point_algo 476.2211875 minutes
#
# Maybe a filler word:
# start_point_algo 478.1311875, end_point_algo 478.2811875, Duration : 0.30999999999994543, confidence:0.966
# start_point_algo 478.1311875 minutes , end_point_algo 478.2811875 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: than start_point_aws: 482.15 end_point_aws: 482.4 Duration : 0.25, Actual_duration: 0.18000000000000682, confidence:1.0
# start_point_algo 482.2111875 minutes , end_point_algo 482.3911875 minutes
#
# Maybe a filler word:
# start_point_algo 501.1111875, end_point_algo 501.3511875, Duration : 0.5299999999999727, confidence:0.817
# start_point_algo 501.1111875 minutes , end_point_algo 501.3511875 minutes
#
# Maybe a filler word:
# start_point_algo 512.2011875000001, end_point_algo 512.5811875, Duration : 0.32000000000005, confidence:1.0
# Maybe a filler word:
# start_point_algo 512.2011875000001, end_point_algo 512.5811875, Duration : 0.20000000000004547, confidence:1.0
# FALSE POSITIVE WORD DETECTED:
# Word: grow start_point_aws: 512.57 end_point_aws: 513.05 Duration : 0.4799999999999045, Actual_duration: 0.37999999999999545, confidence:0.999
# start_point_algo 512.2011875000001 minutes , end_point_algo 512.5811875 minutes
#
# Maybe a filler word:
# start_point_algo 526.0311875, end_point_algo 526.1911875, Duration : 0.40999999999996817, confidence:1.0
# FALSE POSITIVE WORD DETECTED:
# Word: to start_point_aws: 526.18 end_point_aws: 526.29 Duration : 0.11000000000001364, Actual_duration: 0.15999999999996817, confidence:1.0
# start_point_algo 526.0311875 minutes , end_point_algo 526.1911875 minutes
#
# Maybe a filler word:
# start_point_algo 527.8811875, end_point_algo 528.0211875, Duration : 0.14000000000010004, confidence:0.61
# FALSE POSITIVE WORD DETECTED:
# Word: a start_point_aws: 527.94 end_point_aws: 528.04 Duration : 0.09999999999990905, Actual_duration: 0.13999999999998636, confidence:0.963
# start_point_algo 527.8811875 minutes , end_point_algo 528.0211875 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: enough start_point_aws: 532.38 end_point_aws: 532.82 Duration : 0.44000000000005457, Actual_duration: 0.2300000000000182, confidence:1.0
# start_point_algo 532.5111875 minutes , end_point_algo 532.7411875 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: learn start_point_aws: 535.51 end_point_aws: 535.93 Duration : 0.4199999999999591, Actual_duration: 0.14999999999997726, confidence:0.961
# start_point_algo 535.6111875 minutes , end_point_algo 535.7611875 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: around start_point_aws: 543.93 end_point_aws: 544.33 Duration : 0.40000000000009095, Actual_duration: 0.20000000000004547, confidence:1.0
# start_point_algo 544.0411875 minutes , end_point_algo 544.2411875 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: allowed start_point_aws: 550.97 end_point_aws: 551.63 Duration : 0.6599999999999682, Actual_duration: 0.2400000000000091, confidence:1.0
# start_point_algo 551.1911875 minutes , end_point_algo 551.4311875 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: what start_point_aws: 553.97 end_point_aws: 554.22 Duration : 0.25, Actual_duration: 0.14000000000010004, confidence:0.975
# start_point_algo 554.0611875 minutes , end_point_algo 554.2011875000001 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: always start_point_aws: 567.45 end_point_aws: 567.98 Duration : 0.5299999999999727, Actual_duration: 0.1999999999999318, confidence:1.0
# start_point_algo 567.4511875000001 minutes , end_point_algo 567.6511875 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: there start_point_aws: 570.28 end_point_aws: 570.63 Duration : 0.35000000000002274, Actual_duration: 0.13999999999998636, confidence:0.999
# start_point_algo 570.3411875 minutes , end_point_algo 570.4811875 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: Because start_point_aws: 570.64 end_point_aws: 571.46 Duration : 0.82000000000005, Actual_duration: 0.2699999999999818, confidence:1.0
# start_point_algo 571.1211875 minutes , end_point_algo 571.3911875 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: are start_point_aws: 572.61 end_point_aws: 572.82 Duration : 0.21000000000003638, Actual_duration: 0.14999999999997726, confidence:0.997
# start_point_algo 572.6311875 minutes , end_point_algo 572.7811875 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: hurt start_point_aws: 574.71 end_point_aws: 575.15 Duration : 0.4399999999999409, Actual_duration: 0.25, confidence:0.841
# start_point_algo 574.8011875 minutes , end_point_algo 575.0511875 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: allowed start_point_aws: 579.11 end_point_aws: 579.54 Duration : 0.42999999999995, Actual_duration: 0.14999999999997726, confidence:1.0
# start_point_algo 579.3611875 minutes , end_point_algo 579.5111875 minutes
#
# Maybe a filler word:
# start_point_algo 584.3511875, end_point_algo 584.5411875, Duration : 0.5899999999999181, confidence:1.0
# Maybe a filler word:
# start_point_algo 584.3511875, end_point_algo 584.5411875, Duration : 0.10000000000002274, confidence:0.999
# FALSE POSITIVE WORD DETECTED:
# Word: anything start_point_aws: 584.52 end_point_aws: 585.2 Duration : 0.6800000000000637, Actual_duration: 0.18999999999994088, confidence:1.0
# start_point_algo 584.3511875 minutes , end_point_algo 584.5411875 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: order start_point_aws: 591.46 end_point_aws: 592.26 Duration : 0.7999999999999545, Actual_duration: 0.2300000000000182, confidence:0.999
# start_point_algo 591.8611875 minutes , end_point_algo 592.0911875 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: the start_point_aws: 603.23 end_point_aws: 603.77 Duration : 0.5399999999999636, Actual_duration: 0.18000000000006366, confidence:1.0
# start_point_algo 603.3111875 minutes , end_point_algo 603.4911875 minutes
#
# ---------------------------------------AUDIO - 5---------------------------------------
# FALSE POSITIVE WORD DETECTED:
# Word: War start_point_aws: 57.99 end_point_aws: 58.27 Duration : 0.28000000000000114, Actual_duration: 0.14000000000000057, confidence:1.0
# start_point_algo 58.04166666666666 minutes , end_point_algo 58.18166666666666 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: the start_point_aws: 175.04 end_point_aws: 175.53 Duration : 0.4900000000000091, Actual_duration: 0.15000000000000568, confidence:1.0
# start_point_algo 175.23166666666665 minutes , end_point_algo 175.38166666666666 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: here start_point_aws: 234.86 end_point_aws: 235.26 Duration : 0.39999999999997726, Actual_duration: 0.12999999999999545, confidence:0.994
# start_point_algo 235.04166666666666 minutes , end_point_algo 235.17166666666665 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: a start_point_aws: 246.99 end_point_aws: 247.23 Duration : 0.23999999999998067, Actual_duration: 0.15000000000000568, confidence:1.0
# start_point_algo 247.01166666666666 minutes , end_point_algo 247.16166666666666 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: employers start_point_aws: 252.72 end_point_aws: 253.22 Duration : 0.5, Actual_duration: 0.1699999999999875, confidence:0.686
# start_point_algo 252.92166666666665 minutes , end_point_algo 253.09166666666664 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: almost start_point_aws: 261.99 end_point_aws: 262.61 Duration : 0.6200000000000045, Actual_duration: 0.12999999999999545, confidence:1.0
# start_point_algo 262.09166666666664 minutes , end_point_algo 262.22166666666664 minutes
#
# ---------------------------------------AUDIO - 6---------------------------------------
# AWS Filler detection:
# Word: uh, start_time: 47.41, end_time: 47.81
#
# AWS Filler detection:
# Word: uh, start_time: 71.85, end_time: 72.46
#
# AWS Filler detection:
# Word: uh, start_time: 272.82, end_time: 273.35
#
# FALSE POSITIVE WORD DETECTED:
# Word: everyone start_point_aws: 0.17 end_point_aws: 0.53 Duration : 0.36, Actual_duration: 0.22, confidence:1.0
# start_point_algo 0.11999999999998637 minutes , end_point_algo 0.33999999999998637 minutes
#
# Maybe a filler word:
# start_point_algo 5.219999999999986, end_point_algo 5.399999999999986, Duration : 0.41999999999999993, confidence:0.994
# Maybe a filler word:
# start_point_algo 5.219999999999986, end_point_algo 5.399999999999986, Duration : 0.08999999999999986, confidence:1.0
# FALSE POSITIVE WORD DETECTED:
# Word: the start_point_aws: 5.31 end_point_aws: 5.41 Duration : 0.10000000000000053, Actual_duration: 0.17999999999999972, confidence:1.0
# start_point_algo 5.219999999999986 minutes , end_point_algo 5.399999999999986 minutes
#
# Maybe a filler word:
# start_point_algo 7.929999999999986, end_point_algo 8.059999999999988, Duration : 0.17000000000000082, confidence:1.0
# start_point_algo 7.929999999999986 minutes , end_point_algo 8.059999999999988 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: people start_point_aws: 8.06 end_point_aws: 8.61 Duration : 0.5499999999999989, Actual_duration: 0.1899999999999995, confidence:1.0
# start_point_algo 8.409999999999988 minutes , end_point_algo 8.599999999999987 minutes
#
# Maybe a filler word:
# start_point_algo 14.139999999999988, end_point_algo 14.319999999999988, Duration : 0.16000000000000014, confidence:0.96
# FALSE POSITIVE WORD DETECTED:
# Word: the start_point_aws: 14.28 end_point_aws: 14.36 Duration : 0.08000000000000007, Actual_duration: 0.17999999999999972, confidence:1.0
# start_point_algo 14.139999999999988 minutes , end_point_algo 14.319999999999988 minutes
#
# Maybe a filler word:
# start_point_algo 23.979999999999986, end_point_algo 24.209999999999987, Duration : 0.3200000000000003, confidence:1.0
# Maybe a filler word:
# start_point_algo 23.979999999999986, end_point_algo 24.209999999999987, Duration : 0.09999999999999787, confidence:1.0
# FALSE POSITIVE WORD DETECTED:
# Word: saving start_point_aws: 24.13 end_point_aws: 24.49 Duration : 0.35999999999999943, Actual_duration: 0.23000000000000043, confidence:1.0
# start_point_algo 23.979999999999986 minutes , end_point_algo 24.209999999999987 minutes
#
# Maybe a filler word:
# start_point_algo 29.669999999999987, end_point_algo 29.839999999999986, Duration : 0.46000000000000085, confidence:1.0
# FALSE POSITIVE WORD DETECTED:
# Word: are start_point_aws: 29.76 end_point_aws: 29.87 Duration : 0.10999999999999943, Actual_duration: 0.16999999999999815, confidence:1.0
# start_point_algo 29.669999999999987 minutes , end_point_algo 29.839999999999986 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: lost start_point_aws: 37.24 end_point_aws: 37.85 Duration : 0.6099999999999994, Actual_duration: 0.17999999999999972, confidence:1.0
# start_point_algo 37.40999999999999 minutes , end_point_algo 37.58999999999999 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: jobs start_point_aws: 37.98 end_point_aws: 38.42 Duration : 0.44000000000000483, Actual_duration: 0.17999999999999972, confidence:1.0
# start_point_algo 38.09999999999999 minutes , end_point_algo 38.27999999999999 minutes
#
# Maybe a filler word:
# start_point_algo 38.60999999999999, end_point_algo 38.82999999999999, Duration : 0.11999999999999744, confidence:0.997
# Maybe a filler word:
# start_point_algo 38.60999999999999, end_point_algo 38.82999999999999, Duration : 0.07000000000000028, confidence:0.999
# Maybe a filler word:
# start_point_algo 38.60999999999999, end_point_algo 38.82999999999999, Duration : 0.03999999999999915, confidence:1.0
# FALSE POSITIVE WORD DETECTED:
# Word: lot start_point_aws: 38.82 end_point_aws: 39.0 Duration : 0.17999999999999972, Actual_duration: 0.21999999999999886, confidence:1.0
# start_point_algo 38.60999999999999 minutes , end_point_algo 38.82999999999999 minutes
#
# Maybe a filler word:
# start_point_algo 39.49999999999999, end_point_algo 39.62999999999999, Duration : 0.12000000000000455, confidence:0.99
# FALSE POSITIVE WORD DETECTED:
# Word: happened start_point_aws: 39.6 end_point_aws: 39.94 Duration : 0.3399999999999963, Actual_duration: 0.12999999999999545, confidence:1.0
# start_point_algo 39.49999999999999 minutes , end_point_algo 39.62999999999999 minutes
#
# Maybe a filler word:
# start_point_algo 47.37999999999999, end_point_algo 47.52999999999999, Duration : 0.13999999999999346, confidence:0.997
# --------------------------FILLER WORD DETECTED:---------------------
# Word: uh start_point_aws: 47.41, end_point_aws: 47.81 Duration : 0.4000000000000057, Actual_duration: 0.14999999999999858, confidence:0.961
# start_point_algo 47.37999999999999 minutes , end_point_algo 47.52999999999999 minutes
#
# Maybe a filler word:
# start_point_algo 53.55999999999999, end_point_algo 53.71999999999999, Duration : 0.10000000000000142, confidence:1.0
# FALSE POSITIVE WORD DETECTED:
# Word: reside start_point_aws: 53.6 end_point_aws: 54.01 Duration : 0.4099999999999966, Actual_duration: 0.1600000000000037, confidence:0.97
# start_point_algo 53.55999999999999 minutes , end_point_algo 53.71999999999999 minutes
#
# Maybe a filler word:
# start_point_algo 55.97999999999999, end_point_algo 56.13999999999999, Duration : 0.21000000000000085, confidence:1.0
# FALSE POSITIVE WORD DETECTED:
# Word: of start_point_aws: 56.1 end_point_aws: 56.21 Duration : 0.10999999999999943, Actual_duration: 0.1600000000000037, confidence:1.0
# start_point_algo 55.97999999999999 minutes , end_point_algo 56.13999999999999 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: assure start_point_aws: 60.8 end_point_aws: 61.39 Duration : 0.5900000000000034, Actual_duration: 0.18999999999999773, confidence:0.952
# start_point_algo 61.01999999999999 minutes , end_point_algo 61.20999999999999 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: let's start_point_aws: 61.4 end_point_aws: 61.71 Duration : 0.3100000000000023, Actual_duration: 0.15000000000000568, confidence:0.964
# start_point_algo 61.55999999999999 minutes , end_point_algo 61.709999999999994 minutes
#
# Maybe a filler word:
# start_point_algo 61.82999999999999, end_point_algo 62.05999999999999, Duration : 0.17999999999999972, confidence:1.0
# FALSE POSITIVE WORD DETECTED:
# Word: are start_point_aws: 61.98 end_point_aws: 62.06 Duration : 0.0800000000000054, Actual_duration: 0.22999999999999687, confidence:1.0
# start_point_algo 61.82999999999999 minutes , end_point_algo 62.05999999999999 minutes
#
# FALSE POSITIVE WORD DETECTED:
# ...
#
# Maybe a filler word:
# start_point_algo 170.512125, end_point_algo 170.722125, Duration : 0.21999999999999886, confidence:0.906
# FALSE POSITIVE WORD DETECTED:
# Word: to start_point_aws: 170.55 end_point_aws: 170.84 Duration : 0.28999999999999204, Actual_duration: 0.21000000000000796, confidence:1.0
# start_point_algo 170.512125 minutes , end_point_algo 170.722125 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: 0.1-0.4 start_point_aws: 172.26 end_point_aws: 174.18 Duration : 1.920000000000016, Actual_duration: 0.12999999999999545, confidence:0.9945714285714286
# start_point_algo 172.462125 minutes , end_point_algo 172.59212499999998 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: So start_point_aws: 182.14 end_point_aws: 182.96 Duration : 0.8200000000000216, Actual_duration: 0.2400000000000091, confidence:1.0
# start_point_algo 182.37212499999998 minutes , end_point_algo 182.612125 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: year start_point_aws: 203.69 end_point_aws: 204.05 Duration : 0.36000000000001364, Actual_duration: 0.15000000000000568, confidence:0.993
# start_point_algo 203.792125 minutes , end_point_algo 203.942125 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: squaring start_point_aws: 216.23 end_point_aws: 216.8 Duration : 0.5700000000000216, Actual_duration: 0.21000000000000796, confidence:1.0
# start_point_algo 216.552125 minutes , end_point_algo 216.762125 minutes
#
# Maybe a filler word:
# start_point_algo 229.612125, end_point_algo 229.772125, Duration : 0.3599999999999852, confidence:0.88
# FALSE POSITIVE WORD DETECTED:
# Word: to start_point_aws: 229.76 end_point_aws: 229.9 Duration : 0.14000000000001478, Actual_duration: 0.1599999999999966, confidence:0.634
# start_point_algo 229.612125 minutes , end_point_algo 229.772125 minutes
#
# ---------------------------------------AUDIO - 19---------------------------------------
# AWS Filler detection:
# Word: uh, start_time: 1.38, end_time: 2.16
#
# AWS Filler detection:
# Word: Uh, start_time: 17.88, end_time: 18.53
#
# AWS Filler detection:
# Word: Uh, start_time: 24.9, end_time: 26.17
#
# AWS Filler detection:
# Word: uh, start_time: 46.42, end_time: 47.05
#
# AWS Filler detection:
# Word: uh, start_time: 56.55, end_time: 57.3
#
# AWS Filler detection:
# Word: Uh, start_time: 68.68, end_time: 69.27
#
# AWS Filler detection:
# Word: uh, start_time: 76.95, end_time: 78.04
#
# AWS Filler detection:
# Word: uh, start_time: 128.34, end_time: 128.83
#
# AWS Filler detection:
# Word: uh, start_time: 141.27, end_time: 141.76
#
# AWS Filler detection:
# Word: uh, start_time: 143.85, end_time: 144.47
#
# AWS Filler detection:
# Word: uh, start_time: 145.29, end_time: 146.3
#
# AWS Filler detection:
# Word: uh, start_time: 147.04, end_time: 148.22
#
# FALSE POSITIVE WORD DETECTED:
# Word: sir start_point_aws: 4.18 end_point_aws: 4.41 Duration : 0.23000000000000043, Actual_duration: 0.14999999999999947, confidence:0.487
# start_point_algo 4.253354166666669 minutes , end_point_algo 4.403354166666668 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: a start_point_aws: 11.2 end_point_aws: 11.75 Duration : 0.5500000000000007, Actual_duration: 0.20999999999999908, confidence:0.972
# start_point_algo 11.22335416666667 minutes , end_point_algo 11.43335416666667 minutes
#
# --------------------------FILLER WORD DETECTED:---------------------
# Word: Uh start_point_aws: 17.88, end_point_aws: 18.53 Duration : 0.6500000000000021, Actual_duration: 0.3200000000000003, confidence:0.813
# start_point_algo 17.903354166666666 minutes , end_point_algo 18.223354166666667 minutes
#
# --------------------------FILLER WORD DETECTED:---------------------
# Word: Uh start_point_aws: 24.9, end_point_aws: 26.17 Duration : 1.2700000000000031, Actual_duration: 0.379999999999999, confidence:1.0
# start_point_algo 24.96335416666667 minutes , end_point_algo 25.343354166666668 minutes
#
# --------------------------FILLER WORD DETECTED:---------------------
# Word: Uh start_point_aws: 24.9, end_point_aws: 26.17 Duration : 1.2700000000000031, Actual_duration: 0.129999999999999, confidence:1.0
# start_point_algo 25.933354166666668 minutes , end_point_algo 26.063354166666667 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: it start_point_aws: 28.84 end_point_aws: 29.15 Duration : 0.3099999999999987, Actual_duration: 0.21000000000000085, confidence:0.979
# start_point_algo 28.933354166666668 minutes , end_point_algo 29.14335416666667 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: all start_point_aws: 33.63 end_point_aws: 34.42 Duration : 0.7899999999999991, Actual_duration: 0.45999999999999375, confidence:1.0
# start_point_algo 33.753354166666675 minutes , end_point_algo 34.21335416666667 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: a start_point_aws: 36.4 end_point_aws: 36.93 Duration : 0.5300000000000011, Actual_duration: 0.14999999999999858, confidence:1.0
# start_point_algo 36.45335416666667 minutes , end_point_algo 36.60335416666667 minutes
#
# Maybe a filler word:
# start_point_algo 46.403354166666674, end_point_algo 46.62335416666667, Duration : 0.9199999999999946, confidence:1.0
# --------------------------FILLER WORD DETECTED:---------------------
# Word: uh start_point_aws: 46.42, end_point_aws: 47.05 Duration : 0.6299999999999955, Actual_duration: 0.21999999999999886, confidence:1.0
# start_point_algo 46.403354166666674 minutes , end_point_algo 46.62335416666667 minutes
#
# --------------------------FILLER WORD DETECTED:---------------------
# Word: uh start_point_aws: 56.55, end_point_aws: 57.3 Duration : 0.75, Actual_duration: 0.3500000000000014, confidence:1.0
# start_point_algo 56.70335416666667 minutes , end_point_algo 57.05335416666667 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: So start_point_aws: 60.08 end_point_aws: 60.74 Duration : 0.6600000000000037, Actual_duration: 0.1600000000000037, confidence:1.0
# start_point_algo 60.46335416666667 minutes , end_point_algo 60.62335416666667 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: mediocrity start_point_aws: 67.7 end_point_aws: 68.67 Duration : 0.9699999999999989, Actual_duration: 0.14999999999999147, confidence:1.0
# start_point_algo 68.06335416666667 minutes , end_point_algo 68.21335416666666 minutes
#
# --------------------------FILLER WORD DETECTED:---------------------
# Word: uh start_point_aws: 76.95, end_point_aws: 78.04 Duration : 1.0900000000000034, Actual_duration: 0.2599999999999909, confidence:1.0
# start_point_algo 77.20335416666667 minutes , end_point_algo 77.46335416666666 minutes
#
# Maybe a filler word:
# start_point_algo 77.78335416666667, end_point_algo 78.07335416666666, Duration : 1.0900000000000034, confidence:1.0
# FALSE POSITIVE WORD DETECTED:
# Word: drug start_point_aws: 78.05 end_point_aws: 78.3 Duration : 0.25, Actual_duration: 0.28999999999999204, confidence:0.723
# start_point_algo 77.78335416666667 minutes , end_point_algo 78.07335416666666 minutes
#
# Maybe a filler word:
# start_point_algo 81.32335416666666, end_point_algo 81.46335416666666, Duration : 0.4099999999999966, confidence:1.0
# FALSE POSITIVE WORD DETECTED:
# Word: that start_point_aws: 81.43 end_point_aws: 81.69 Duration : 0.2599999999999909, Actual_duration: 0.14000000000000057, confidence:1.0
# start_point_algo 81.32335416666666 minutes , end_point_algo 81.46335416666666 minutes
#
# Maybe a filler word:
# start_point_algo 82.93335416666666, end_point_algo 83.10335416666666, Duration : 0.23000000000000398, confidence:1.0
# FALSE POSITIVE WORD DETECTED:
# Word: a start_point_aws: 82.94 end_point_aws: 83.18 Duration : 0.2400000000000091, Actual_duration: 0.1700000000000017, confidence:0.571
# start_point_algo 82.93335416666666 minutes , end_point_algo 83.10335416666666 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: sector start_point_aws: 84.47 end_point_aws: 85.07 Duration : 0.5999999999999943, Actual_duration: 0.20000000000000284, confidence:0.989
# start_point_algo 84.85335416666666 minutes , end_point_algo 85.05335416666667 minutes
#
# Maybe a filler word:
# start_point_algo 94.87335416666667, end_point_algo 95.00335416666667, Duration : 0.4200000000000017, confidence:1.0
# FALSE POSITIVE WORD DETECTED:
# Word: are start_point_aws: 94.95 end_point_aws: 95.09 Duration : 0.14000000000000057, Actual_duration: 0.12999999999999545, confidence:1.0
# start_point_algo 94.87335416666667 minutes , end_point_algo 95.00335416666667 minutes
#
# Maybe a filler word:
# start_point_algo 114.10335416666666, end_point_algo 114.25335416666667, Duration : 0.20000000000000284, confidence:1.0
# FALSE POSITIVE WORD DETECTED:
# Word: only start_point_aws: 114.25 end_point_aws: 114.63 Duration : 0.37999999999999545, Actual_duration: 0.15000000000000568, confidence:0.999
# start_point_algo 114.10335416666666 minutes , end_point_algo 114.25335416666667 minutes
#
# Maybe a filler word:
# start_point_algo 127.69335416666667, end_point_algo 127.88335416666666, Duration : 0.7599999999999909, confidence:1.0
# start_point_algo 127.69335416666667 minutes , end_point_algo 127.88335416666666 minutes
#
# Maybe a filler word:
# start_point_algo 128.5733541666667, end_point_algo 128.86335416666668, Duration : 0.4900000000000091, confidence:0.959
# FALSE POSITIVE WORD DETECTED:
# Word: make start_point_aws: 128.84 end_point_aws: 129.11 Duration : 0.27000000000001023, Actual_duration: 0.28999999999999204, confidence:1.0
# start_point_algo 128.5733541666667 minutes , end_point_algo 128.86335416666668 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: I'm start_point_aws: 137.95 end_point_aws: 138.63 Duration : 0.6800000000000068, Actual_duration: 0.13999999999998636, confidence:0.947
# start_point_algo 138.3233541666667 minutes , end_point_algo 138.46335416666668 minutes
#
# Maybe a filler word:
# start_point_algo 141.56335416666667, end_point_algo 141.80335416666668, Duration : 0.4899999999999807, confidence:0.719
# FALSE POSITIVE WORD DETECTED:
# Word: achieving start_point_aws: 141.77 end_point_aws: 142.27 Duration : 0.5, Actual_duration: 0.2400000000000091, confidence:1.0
# start_point_algo 141.56335416666667 minutes , end_point_algo 141.80335416666668 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: mediocrity start_point_aws: 154.72 end_point_aws: 155.75 Duration : 1.0300000000000011, Actual_duration: 0.1699999999999875, confidence:1.0
# start_point_algo 154.9833541666667 minutes , end_point_algo 155.15335416666667 minutes
#
# ---------------------------------------AUDIO - 20---------------------------------------
# AWS Filler detection:
# Word: uh, start_time: 25.64, end_time: 26.69
#
# AWS Filler detection:
# Word: uh, start_time: 55.23, end_time: 56.25
#
# AWS Filler detection:
# Word: uh, start_time: 223.42, end_time: 224.33
#
# Maybe a filler word:
# start_point_algo 0.5316666666666515 minutes , end_point_algo 0.7516666666666515 minutes
#
# --------------------------FILLER WORD DETECTED:---------------------
# Word: uh start_point_aws: 25.64, end_point_aws: 26.69 Duration : 1.0500000000000007, Actual_duration: 0.15000000000000213, confidence:1.0
# start_point_algo 26.15166666666665 minutes , end_point_algo 26.30166666666665 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: will start_point_aws: 32.88 end_point_aws: 33.19 Duration : 0.30999999999999517, Actual_duration: 0.1599999999999966, confidence:1.0
# start_point_algo 32.97166666666666 minutes , end_point_algo 33.13166666666665 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: the start_point_aws: 34.02 end_point_aws: 34.62 Duration : 0.5999999999999943, Actual_duration: 0.14000000000000057, confidence:1.0
# start_point_algo 34.081666666666656 minutes , end_point_algo 34.22166666666666 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: So start_point_aws: 35.5 end_point_aws: 36.32 Duration : 0.8200000000000003, Actual_duration: 0.23999999999999488, confidence:1.0
# start_point_algo 35.93166666666666 minutes , end_point_algo 36.17166666666665 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: caused start_point_aws: 37.37 end_point_aws: 37.9 Duration : 0.5300000000000011, Actual_duration: 0.20000000000000284, confidence:1.0
# start_point_algo 37.521666666666654 minutes , end_point_algo 37.72166666666666 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: harms start_point_aws: 58.89 end_point_aws: 59.69 Duration : 0.7999999999999972, Actual_duration: 0.3200000000000003, confidence:1.0
# start_point_algo 58.911666666666655 minutes , end_point_algo 59.231666666666655 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: cause start_point_aws: 82.33 end_point_aws: 82.7 Duration : 0.37000000000000455, Actual_duration: 0.12999999999999545, confidence:1.0
# start_point_algo 82.47166666666665 minutes , end_point_algo 82.60166666666665 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: the start_point_aws: 88.95 end_point_aws: 89.65 Duration : 0.7000000000000028, Actual_duration: 0.269999999999996, confidence:1.0
# start_point_algo 89.03166666666665 minutes , end_point_algo 89.30166666666665 minutes
#
# Maybe a filler word:
# start_point_algo 127.03166666666665, end_point_algo 127.18166666666664, Duration : 0.45000000000000284, confidence:0.971
# FALSE POSITIVE WORD DETECTED:
# Word: gashes start_point_aws: 127.16 end_point_aws: 127.72 Duration : 0.5600000000000023, Actual_duration: 0.14999999999999147, confidence:0.747
# start_point_algo 127.03166666666665 minutes , end_point_algo 127.18166666666664 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: We start_point_aws: 130.93 end_point_aws: 131.47 Duration : 0.539999999999992, Actual_duration: 0.21999999999999886, confidence:0.355
# start_point_algo 131.20166666666665 minutes , end_point_algo 131.42166666666665 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: impaired start_point_aws: 150.46 end_point_aws: 150.92 Duration : 0.45999999999997954, Actual_duration: 0.13999999999998636, confidence:1.0
# start_point_algo 150.70166666666665 minutes , end_point_algo 150.84166666666664 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: for start_point_aws: 159.04 end_point_aws: 159.78 Duration : 0.7400000000000091, Actual_duration: 0.1599999999999966, confidence:1.0
# start_point_algo 159.18166666666664 minutes , end_point_algo 159.34166666666664 minutes
#
# FILLER WORD:
# Word: for start_point_aws: 159.04 end_point_aws: 159.78Duration : 0.7400000000000091, Actual_duration: 0.1699999999999875, confidence:1.0
# start_point_algo 159.42166666666665 minutes , end_point_algo 159.59166666666664 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: causes start_point_aws: 190.86 end_point_aws: 191.4 Duration : 0.539999999999992, Actual_duration: 0.1599999999999966, confidence:0.691
# start_point_algo 190.93166666666664 minutes , end_point_algo 191.09166666666664 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: dot start_point_aws: 200.01 end_point_aws: 200.59 Duration : 0.5800000000000125, Actual_duration: 0.17000000000001592, confidence:1.0
# start_point_algo 200.18166666666664 minutes , end_point_algo 200.35166666666666 minutes
#
# FALSE POSITIVE WORD DETECTED:
# Word: does start_point_aws: 200.68 end_point_aws: 201.19 Duration : 0.5099999999999909, Actual_duration: 0.2599999999999909, confidence:0.64
# start_point_algo 200.79166666666666 minutes , end_point_algo 201.05166666666665 minutes
#
# Maybe a filler word:
# start_point_algo 216.52166666666665, end_point_algo 216.68166666666664, Duration : 0.4099999999999966, confidence:1.0
# FALSE POSITIVE WORD DETECTED:
# Word: protects start_point_aws: 216.65 end_point_aws: 217.25 Duration : 0.5999999999999943, Actual_duration: 0.1599999999999966, confidence:1.0
# start_point_algo 216.52166666666665 minutes , end_point_algo 216.68166666666664 minutes
#
# --------------------------FILLER WORD DETECTED:---------------------
# Word: uh start_point_aws: 223.42, end_point_aws: 224.33 Duration : 0.910000000000025, Actual_duration: 0.5500000000000114, confidence:1.0
# start_point_algo 223.43166666666664 minutes , end_point_algo 223.98166666666665 minutes
#
# Maybe a filler word:
# start_point_algo 229.67166666666665, end_point_algo 230.05166666666665, Duration : 0.8700000000000045, confidence:1.0
# FALSE POSITIVE WORD DETECTED:
# Word: and start_point_aws: 230.02 end_point_aws: 230.14 Duration : 0.11999999999997613, Actual_duration: 0.37999999999999545, confidence:0.663
# start_point_algo 229.67166666666665 minutes , end_point_algo 230.05166666666665 minutes
